# %% [markdown]
# <font size="+3">OpenDDE benchmark on TCR:epitope interactions</font> <br>

# %%
import glob
import os
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.decomposition import PCA

from Bio.PDB import PDBParser, NeighborSearch, PDBIO, Superimposer, MMCIFParser
from Bio.SeqUtils import seq1

# %% [markdown]
# # IMMREP23

# %%
df = pd.read_csv('IMMREP23_unseen.csv')
df = df.rename(columns={'model':'epitope', 'epitope':'peptide', 'MHC':'MHC_allele_a'})
df = df.drop(columns=['MHC_class'])
df['MHC_allele_a'] = 'HLA_' + df['MHC_allele_a']
df = df[df['peptide'].isin(['SALPTNADLY', 'TDLGQNLLY', 'VSDGGPNLY'])]
df = df.sort_values(by='peptide')
df['id'] = [f'tcr_{i:04}' for i in range(len(df))]
# move 'id' to the first column position
df.insert(0, 'id', df.pop('id'))

genes = ['TRAV', 'TRAJ', 'TRBV', 'TRBJ']
for g in genes:
    df[g] = df[g].str.split('*').str[0]

df.to_csv('IMMREP23_unseen_clean.csv', index=False)
# Out:
#            id           epitope         cdr3_TRA          cdr3_TRB  \
# 0    tcr_0000  A0101_SALPTNADLY     CAVGDNFNKFYF    CASAPTSAMGEQYF
# 452  tcr_0001  A0101_SALPTNADLY     CAVRGSNYQLIW      CASSPHSYEQYF
# 129  tcr_0002  A0101_SALPTNADLY  CAYRSAVGSQGNLIF  CAISELGGGSNTEAFF
# 626  tcr_0003  A0101_SALPTNADLY    CVARGGATNKLIF  CASSLIFAGRGAEAFF
# 126  tcr_0004  A0101_SALPTNADLY      CAVSPGTRLMF    CQQFSGQGNLRAVF
#
#              TRAV    TRAJ      TRBV     TRBJ      species MHC_allele_a  \
# 0         TRAV8-3  TRAJ21    TRBV28  TRBJ2-7  HomoSapiens    HLA_A0101
# 452        TRAV21  TRAJ33   TRBV5-4  TRBJ2-7  HomoSapiens    HLA_A0101
# 129  TRAV38-2/DV8  TRAJ42  TRBV10-3  TRBJ1-1  HomoSapiens    HLA_A0101
# 626      TRAV12-1  TRAJ32  TRBV12-4  TRBJ1-1  HomoSapiens    HLA_A0101
# 126        TRAV21  TRAJ31  TRBV12-3  TRBJ2-7  HomoSapiens    HLA_A0101
#
#         peptide  Label
# 0    SALPTNADLY      0
# 452  SALPTNADLY      0
# 129  SALPTNADLY      1
# 626  SALPTNADLY      0
# 126  SALPTNADLY      0

# %%
df_input = pd.read_csv('IMMREP23_unseen_clean.csv')
df_input = df_input.drop(columns = ['Unnamed: 0'])
df_input = df_input.rename(columns={'Label':'label'})

epitopes = ['A0101_SALPTNADLY', 'A0101_TDLGQNLLY', 'A0101_VSDGGPNLY']
lst = []
for epitope in epitopes:
    df = pd.read_csv(f'IMMREP23/{epitope}/output.csv')
    lst.append(df)

df_output = pd.concat(lst)
df_output.to_csv(f'IMMREP23/output.csv', index=False)
df_output.columns = df_output.columns.str.lower()

df = pd.merge(df_input, df_output, on='id')

df['epitope'] = df['MHC_allele_a'].str[4:] + '_' + df['peptide']
df.to_csv(f'IMMREP23/output_anno.csv')

# %%
fig, axes = plt.subplots(1, 3, figsize=(9, 2.7), sharex=True, sharey=True)

topdirs = {'ESMFold2 - single sequence' : '../260617_test_ESMFold2/IMMREP23/single-sequence', 
           'ESMFold2 - msa' :'../260617_test_ESMFold2/IMMREP23/msa', 
           'Protenix-v2 - msa' :'../260723_test_protenix/IMMREP23',
           'OpenDDE - msa' :'IMMREP23'}

colors = {
    'ESMFold2 - single sequence': 'C0',
    'ESMFold2 - msa': 'C1',
    'Protenix-v2 - msa': 'C2',
    'OpenDDE - msa': 'C3',
}

legend_handles = []

for i, (label, topdir) in enumerate(topdirs.items()):
    df = pd.read_csv(f'{topdir}/output_anno.csv')
    print(df)
    color = colors[label]

    topdir_records = []

    for cnt, (name, group) in enumerate(df.groupby('epitope')):
        ax = axes[cnt]

        y_true = group['label'].values
        y_scores = group['iptm_pair_mean'].values

        fpr, tpr, _ = roc_curve(y_true, y_scores)
        auc = roc_auc_score(y_true, y_scores)
        auc01 = roc_auc_score(y_true, y_scores, max_fpr=0.1)

        line, = ax.plot(fpr, tpr, color=color)

        ax.set_title(name, fontsize='small')

        # stack AUC01 labels for up to 3 topdirs without overlapping
        y_pos = 0.3 - 0.08 * i
        ax.text(0.95, y_pos, f"AUC01 = {auc01:.3f}", transform=ax.transAxes,
                ha='right', va='bottom', fontsize='small', color=color)

        ax.set_xlabel('FPR')
        if cnt == 0:
            ax.set_ylabel('TPR')

        topdir_records.append({'epitope': name, 'auc': auc, 'auc01': auc01})

        if cnt == 0:
            legend_handles.append(line)

    df_auc = pd.DataFrame(topdir_records)
    #df_auc.to_csv(f'IMMREP23/{topdir}/output_auc.csv', index=False)
    print(topdir)
    print(df_auc.head())

sns.despine()
fig.legend(legend_handles, topdirs, loc='upper left',
           bbox_to_anchor=(0.9, 1.0), frameon=False)
# Out:
#      Unnamed: 0        id           epitope         cdr3_TRA  \
# 0             0  tcr_0000  A0101_SALPTNADLY     CAVGDNFNKFYF
# 1             1  tcr_0001  A0101_SALPTNADLY     CAVRGSNYQLIW
# 2             2  tcr_0002  A0101_SALPTNADLY  CAYRSAVGSQGNLIF
# 3             3  tcr_0003  A0101_SALPTNADLY    CVARGGATNKLIF
# 4             4  tcr_0004  A0101_SALPTNADLY      CAVSPGTRLMF
# ..          ...       ...               ...              ...
# 647         647  tcr_0647   A0101_VSDGGPNLY   CAASTGGSQGNLIF
# 648         648  tcr_0648   A0101_VSDGGPNLY    CVARGGATNKLIF
# 649         649  tcr_0649   A0101_VSDGGPNLY    CAPNKAAGNKLTF
# 650         650  tcr_0650   A0101_VSDGGPNLY  CALSETGRDTDKLIF
# 651         651  tcr_0651   A0101_VSDGGPNLY   CVVNKGAGGFKTIF
#
#              cdr3_TRB          TRAV    TRAJ      TRBV     TRBJ      species  \
# 0      CASAPTSAMGEQYF       TRAV8-3  TRAJ21    TRBV28  TRBJ2-7  HomoSapiens
# 1        CASSPHSYEQYF        TRAV21  TRAJ33   TRBV5-4  TRBJ2-7  HomoSapiens
# 2    CAISELGGGSNTEAFF  TRAV38-2/DV8  TRAJ42  TRBV10-3  TRBJ1-1  HomoSapiens
# 3    CASSLIFAGRGAEAFF      TRAV12-1  TRAJ32  TRBV12-4  TRBJ1-1  HomoSapiens
# 4      CQQFSGQGNLRAVF        TRAV21  TRAJ31  TRBV12-3  TRBJ2-7  HomoSapiens
# ..                ...           ...     ...       ...      ...          ...
# 647     CASSIRSTGELFF        TRAV25  TRAJ42    TRBV19  TRBJ2-2  HomoSapiens
# 648    CAISTGDGNQPQHF      TRAV12-1  TRAJ32  TRBV10-3  TRBJ1-5  HomoSapiens
# 649     CAAGGRRDTEAFF        TRAV16  TRAJ17   TRBV7-9  TRBJ1-1  HomoSapiens
# 650    CASSLAGEGYEQYF        TRAV19  TRAJ34   TRBV7-6  TRBJ2-7  HomoSapiens
# 651    CAWRTLDSNSPLHF      TRAV12-1   TRAJ9    TRBV30  TRBJ1-6  HomoSapiens
#
#     MHC_allele_a     peptide  label    iptm     ptm  plddt_mean  \
# 0      HLA_A0101  SALPTNADLY      0  0.7905  0.8302      0.8965
# 1      HLA_A0101  SALPTNADLY      0  0.8468  0.8799      0.8959
# 2      HLA_A0101  SALPTNADLY      1  0.5887  0.6521      0.8751
# 3      HLA_A0101  SALPTNADLY      0  0.6560  0.7095      0.8785
# 4      HLA_A0101  SALPTNADLY      0  0.8932  0.9233      0.9058
# ..           ...         ...    ...     ...     ...         ...
# 647    HLA_A0101   VSDGGPNLY      0  0.8237  0.8623      0.8935
# 648    HLA_A0101   VSDGGPNLY      0  0.8179  0.8561      0.8935
# 649    HLA_A0101   VSDGGPNLY      0  0.7572  0.8024      0.8702
# 650    HLA_A0101   VSDGGPNLY      0  0.7366  0.7809      0.8919
# 651    HLA_A0101   VSDGGPNLY      0  0.8071  0.8444      0.8824
#
#      fold_time_seconds  iptm_pair_mean
# 0                16.51          0.5149
# 1                15.64          0.5750
# 2                19.94          0.1657
# 3                20.46          0.2795
# 4                18.77          0.6746
# ..                 ...             ...
# 647              18.42          0.5636
# 648              15.73          0.5646
# 649              18.83          0.4373
# 650              19.44          0.4216
# 651              18.41          0.5333
#
# [652 rows x 18 columns]
# ../260617_test_ESMFold2/IMMREP23/single-sequence
#             epitope       auc     auc01
# 0  A0101_SALPTNADLY  0.420370  0.480182
# 1   A0101_TDLGQNLLY  0.694215  0.514282
# 2   A0101_VSDGGPNLY  0.768558  0.665696
#      Unnamed: 0        id           epitope         cdr3_TRA  \
# 0             0  tcr_0000  A0101_SALPTNADLY     CAVGDNFNKFYF
# 1             1  tcr_0001  A0101_SALPTNADLY     CAVRGSNYQLIW
# 2             2  tcr_0002  A0101_SALPTNADLY  CAYRSAVGSQGNLIF
# 3             3  tcr_0003  A0101_SALPTNADLY    CVARGGATNKLIF
# 4             4  tcr_0004  A0101_SALPTNADLY      CAVSPGTRLMF
# ..          ...       ...               ...              ...
# 647         647  tcr_0647   A0101_VSDGGPNLY   CAASTGGSQGNLIF
# 648         648  tcr_0648   A0101_VSDGGPNLY    CVARGGATNKLIF
# 649         649  tcr_0649   A0101_VSDGGPNLY    CAPNKAAGNKLTF
# 650         650  tcr_0650   A0101_VSDGGPNLY  CALSETGRDTDKLIF
# 651         651  tcr_0651   A0101_VSDGGPNLY   CVVNKGAGGFKTIF
#
#              cdr3_TRB          TRAV    TRAJ      TRBV     TRBJ      species  \
# 0      CASAPTSAMGEQYF       TRAV8-3  TRAJ21    TRBV28  TRBJ2-7  HomoSapiens
# 1        CASSPHSYEQYF        TRAV21  TRAJ33   TRBV5-4  TRBJ2-7  HomoSapiens
# 2    CAISELGGGSNTEAFF  TRAV38-2/DV8  TRAJ42  TRBV10-3  TRBJ1-1  HomoSapiens
# 3    CASSLIFAGRGAEAFF      TRAV12-1  TRAJ32  TRBV12-4  TRBJ1-1  HomoSapiens
# 4      CQQFSGQGNLRAVF        TRAV21  TRAJ31  TRBV12-3  TRBJ2-7  HomoSapiens
# ..                ...           ...     ...       ...      ...          ...
# 647     CASSIRSTGELFF        TRAV25  TRAJ42    TRBV19  TRBJ2-2  HomoSapiens
# 648    CAISTGDGNQPQHF      TRAV12-1  TRAJ32  TRBV10-3  TRBJ1-5  HomoSapiens
# 649     CAAGGRRDTEAFF        TRAV16  TRAJ17   TRBV7-9  TRBJ1-1  HomoSapiens
# 650    CASSLAGEGYEQYF        TRAV19  TRAJ34   TRBV7-6  TRBJ2-7  HomoSapiens
# 651    CAWRTLDSNSPLHF      TRAV12-1   TRAJ9    TRBV30  TRBJ1-6  HomoSapiens
#
#     MHC_allele_a     peptide  label    iptm     ptm  plddt_mean  \
# 0      HLA_A0101  SALPTNADLY      0  0.7060  0.7561      0.8914
# 1      HLA_A0101  SALPTNADLY      0  0.8532  0.8762      0.9026
# 2      HLA_A0101  SALPTNADLY      1  0.7558  0.7981      0.8944
# 3      HLA_A0101  SALPTNADLY      0  0.7356  0.7763      0.8975
# 4      HLA_A0101  SALPTNADLY      0  0.8848  0.9031      0.9033
# ..           ...         ...    ...     ...     ...         ...
# 647    HLA_A0101   VSDGGPNLY      0  0.7461  0.7908      0.8939
# 648    HLA_A0101   VSDGGPNLY      0  0.6044  0.6596      0.8811
# 649    HLA_A0101   VSDGGPNLY      0  0.7310  0.7747      0.8795
# 650    HLA_A0101   VSDGGPNLY      0  0.6592  0.7122      0.8950
# 651    HLA_A0101   VSDGGPNLY      0  0.8797  0.8985      0.9011
#
#      fold_time_seconds  iptm_pair_mean
# 0                35.46          0.3618
# 1                35.75          0.5669
# 2                43.97          0.4181
# 3                44.65          0.3645
# 4                41.33          0.6243
# ..                 ...             ...
# 647              40.62          0.4177
# 648              35.34          0.1589
# 649              41.08          0.3685
# 650              42.55          0.2823
# 651              40.46          0.6378
#
# [652 rows x 18 columns]
# ../260617_test_ESMFold2/IMMREP23/msa
#             epitope       auc     auc01
# 0  A0101_SALPTNADLY  0.543827  0.476933
# 1   A0101_TDLGQNLLY  0.729109  0.554396
# 2   A0101_VSDGGPNLY  0.740212  0.634755
#      Unnamed: 0        id           epitope         cdr3_TRA  \
# 0             0  tcr_0000  A0101_SALPTNADLY     CAVGDNFNKFYF
# 1             1  tcr_0001  A0101_SALPTNADLY     CAVRGSNYQLIW
# 2             2  tcr_0002  A0101_SALPTNADLY  CAYRSAVGSQGNLIF
# 3             3  tcr_0003  A0101_SALPTNADLY    CVARGGATNKLIF
# 4             4  tcr_0004  A0101_SALPTNADLY      CAVSPGTRLMF
# ..          ...       ...               ...              ...
# 647         647  tcr_0647   A0101_VSDGGPNLY   CAASTGGSQGNLIF
# 648         648  tcr_0648   A0101_VSDGGPNLY    CVARGGATNKLIF
# 649         649  tcr_0649   A0101_VSDGGPNLY    CAPNKAAGNKLTF
# 650         650  tcr_0650   A0101_VSDGGPNLY  CALSETGRDTDKLIF
# 651         651  tcr_0651   A0101_VSDGGPNLY   CVVNKGAGGFKTIF
#
#              cdr3_TRB          TRAV    TRAJ      TRBV     TRBJ      species  \
# 0      CASAPTSAMGEQYF       TRAV8-3  TRAJ21    TRBV28  TRBJ2-7  HomoSapiens
# 1        CASSPHSYEQYF        TRAV21  TRAJ33   TRBV5-4  TRBJ2-7  HomoSapiens
# 2    CAISELGGGSNTEAFF  TRAV38-2/DV8  TRAJ42  TRBV10-3  TRBJ1-1  HomoSapiens
# 3    CASSLIFAGRGAEAFF      TRAV12-1  TRAJ32  TRBV12-4  TRBJ1-1  HomoSapiens
# 4      CQQFSGQGNLRAVF        TRAV21  TRAJ31  TRBV12-3  TRBJ2-7  HomoSapiens
# ..                ...           ...     ...       ...      ...          ...
# 647     CASSIRSTGELFF        TRAV25  TRAJ42    TRBV19  TRBJ2-2  HomoSapiens
# 648    CAISTGDGNQPQHF      TRAV12-1  TRAJ32  TRBV10-3  TRBJ1-5  HomoSapiens
# 649     CAAGGRRDTEAFF        TRAV16  TRAJ17   TRBV7-9  TRBJ1-1  HomoSapiens
# 650    CASSLAGEGYEQYF        TRAV19  TRAJ34   TRBV7-6  TRBJ2-7  HomoSapiens
# 651    CAWRTLDSNSPLHF      TRAV12-1   TRAJ9    TRBV30  TRBJ1-6  HomoSapiens
#
#      ...     peptide label       ptm      iptm      plddt  ranking_score  \
# 0    ...  SALPTNADLY     0  0.724147  0.666742  89.745506       0.678223
# 1    ...  SALPTNADLY     0  0.889919  0.859569  92.671387       0.865639
# 2    ...  SALPTNADLY     1  0.710064  0.657857  90.630646       0.668299
# 3    ...  SALPTNADLY     0  0.729138  0.680306  89.013329       0.690073
# 4    ...  SALPTNADLY     0  0.807893  0.761472  90.648537       0.770756
# ..   ...         ...   ...       ...       ...        ...            ...
# 647  ...   VSDGGPNLY     0  0.821875  0.780011  91.685448       0.788384
# 648  ...   VSDGGPNLY     0  0.851848  0.814905  92.211334       0.822293
# 649  ...   VSDGGPNLY     0  0.742709  0.694058  88.671509       0.703788
# 650  ...   VSDGGPNLY     0  0.771600  0.717485  91.356346       0.728308
# 651  ...   VSDGGPNLY     0  0.895790  0.863049  92.323738       0.869597
#
#      has_clash  iptm_pair_mean  n_chains  fold_time_seconds
# 0        False        0.293612         5              46.60
# 1        False        0.725098         5              44.97
# 2        False        0.234788         5              47.94
# 3        False        0.243091         5              44.38
# 4        False        0.494525         5              51.61
# ..         ...             ...       ...                ...
# 647      False        0.539420         5              46.25
# 648      False        0.579315         5              44.83
# 649      False        0.316384         5              45.78
# 650      False        0.378899         5              47.20
# 651      False        0.702510         5              46.11
#
# [652 rows x 21 columns]
# ../260723_test_protenix/IMMREP23
#             epitope       auc     auc01
# 0  A0101_SALPTNADLY  0.214198  0.473684
# 1   A0101_TDLGQNLLY  0.663545  0.539897
# 2   A0101_VSDGGPNLY  0.755089  0.617173
#      Unnamed: 0        id           epitope         cdr3_TRA  \
# 0             0  tcr_0000  A0101_SALPTNADLY     CAVGDNFNKFYF
# 1             1  tcr_0001  A0101_SALPTNADLY     CAVRGSNYQLIW
# 2             2  tcr_0002  A0101_SALPTNADLY  CAYRSAVGSQGNLIF
# 3             3  tcr_0003  A0101_SALPTNADLY    CVARGGATNKLIF
# 4             4  tcr_0004  A0101_SALPTNADLY      CAVSPGTRLMF
# ..          ...       ...               ...              ...
# 647         647  tcr_0647   A0101_VSDGGPNLY   CAASTGGSQGNLIF
# 648         648  tcr_0648   A0101_VSDGGPNLY    CVARGGATNKLIF
# 649         649  tcr_0649   A0101_VSDGGPNLY    CAPNKAAGNKLTF
# 650         650  tcr_0650   A0101_VSDGGPNLY  CALSETGRDTDKLIF
# 651         651  tcr_0651   A0101_VSDGGPNLY   CVVNKGAGGFKTIF
#
#              cdr3_TRB          TRAV    TRAJ      TRBV     TRBJ      species  \
# 0      CASAPTSAMGEQYF       TRAV8-3  TRAJ21    TRBV28  TRBJ2-7  HomoSapiens
# 1        CASSPHSYEQYF        TRAV21  TRAJ33   TRBV5-4  TRBJ2-7  HomoSapiens
# 2    CAISELGGGSNTEAFF  TRAV38-2/DV8  TRAJ42  TRBV10-3  TRBJ1-1  HomoSapiens
# 3    CASSLIFAGRGAEAFF      TRAV12-1  TRAJ32  TRBV12-4  TRBJ1-1  HomoSapiens
# 4      CQQFSGQGNLRAVF        TRAV21  TRAJ31  TRBV12-3  TRBJ2-7  HomoSapiens
# ..                ...           ...     ...       ...      ...          ...
# 647     CASSIRSTGELFF        TRAV25  TRAJ42    TRBV19  TRBJ2-2  HomoSapiens
# 648    CAISTGDGNQPQHF      TRAV12-1  TRAJ32  TRBV10-3  TRBJ1-5  HomoSapiens
# 649     CAAGGRRDTEAFF        TRAV16  TRAJ17   TRBV7-9  TRBJ1-1  HomoSapiens
# 650    CASSLAGEGYEQYF        TRAV19  TRAJ34   TRBV7-6  TRBJ2-7  HomoSapiens
# 651    CAWRTLDSNSPLHF      TRAV12-1   TRAJ9    TRBV30  TRBJ1-6  HomoSapiens
#
#      ... label       ptm      iptm      gpde      plddt  ranking_score  \
# 0    ...     0  0.810422  0.753224  0.516311  94.676750       0.764664
# 1    ...     0  0.709580  0.654214  0.583220  93.074287       0.665287
# 2    ...     1  0.793099  0.746631  0.522426  94.301666       0.755925
# 3    ...     0  0.844304  0.789566  0.494366  94.678978       0.800514
# 4    ...     0  0.883911  0.846407  0.477052  94.820389       0.853908
# ..   ...   ...       ...       ...       ...        ...            ...
# 647  ...     0  0.728842  0.671795  0.571937  94.157585       0.683204
# 648  ...     0  0.812316  0.777543  0.534558  94.797821       0.784497
# 649  ...     0  0.706672  0.652832  0.688423  91.416130       0.663600
# 650  ...     0  0.949253  0.929977  0.424358  96.320999       0.933832
# 651  ...     0  0.700095  0.647292  0.607615  93.489799       0.657853
#
#      has_clash  iptm_pair_mean  n_chains  fold_time_seconds
# 0        False        0.507567         5             119.83
# 1        False        0.220674         5             115.82
# 2        False        0.467253         5             121.52
# 3        False        0.523321         5             116.96
# 4        False        0.673873         5             120.08
# ..         ...             ...       ...                ...
# 647      False        0.260033         5             120.91
# 648      False        0.370177         5             116.89
# 649      False        0.189544         5             118.78
# 650      False        0.853400         5             123.16
# 651      False        0.169813         5             120.01
#
# [652 rows x 22 columns]
# IMMREP23
#             epitope       auc     auc01
# 0  A0101_SALPTNADLY  0.562346  0.499675
# 1   A0101_TDLGQNLLY  0.665565  0.600793
# 2   A0101_VSDGGPNLY  0.757124  0.643010
